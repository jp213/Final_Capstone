# %% [markdown]
# # Final Capstone
#
# ## Notebook 3: Separation of training and quiz sets

# %%
import time
start_time = time.perf_counter()
import numpy as np
import pandas as pd
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
# %%time
# import main df and quiz index list
base_path = 'C:/Users/jnpol/Documents/DS/Data Science/UL/'
quindex = pd.read_parquet(base_path + 'quindex.parquet')
quilist = list(quindex.quindex)
net = pd.read_parquet(base_path + 'net2.parquet')
net.info()
net.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97713135 entries, 61342875 to 6598294
# Data columns (total 19 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   mov_id           int16
#  1   cust_id          int32
#  2   rating           float64
#  3   day_rated        int16
#  4   mov_year         int16
#  5   mov_count        int32
#  6   rated_bycust     int16
#  7   rate_each_day    int32
#  8   mov_day_count    uint16
#  9   cust_day_count   int16
#  10  mov_avg_rating   float32
#  11  cust_avg_rating  float32
#  12  mov_day_avg_rl   float32
#  13  mov_day_avg      float32
#  14  cust_avg_offset  float32
#  15  cust_day_avg     float32
#  16  avg_rate_mov_yr  float32
#  17  avg_rate_cst_yr  float32
#  18  all_ratings      int8
# dtypes: float32(8), float64(1), int16(5), int32(3), int8(1), uint16(1)
# memory usage: 6.6 GB
# Wall time: 4.5 s
#           mov_id  cust_id  rating  day_rated  mov_year  mov_count  \
# 61342875   11182   549302    4.00       1696      2003     103062
# 12081331    2342  1077245    3.00       1976      2004      87480
# 99011741   17474  2463816    4.00       1567      1964      32089
# 73636568   13372  2204684    3.00       1225      2002        350
# 66797623   12191  2032601    3.00       1679      1996      12782
#
#           rated_bycust  rate_each_day  mov_day_count  cust_day_count  \
# 61342875           459          70730            296             106
# 12081331           139          98810            126               3
# 99011741          1577          83753             41               7
# 73636568           829          15570              1               5
# 66797623          1219          97725             34               6
#
#           mov_avg_rating  cust_avg_rating  mov_day_avg_rl  mov_day_avg  \
# 61342875            3.55             3.79            3.53         3.53
# 12081331            3.87             4.27            3.72         3.72
# 99011741            4.09             3.08            4.20         4.20
# 73636568            2.69             3.26            3.00         3.00
# 66797623            2.97             3.48            2.65         2.65
#
#           cust_avg_offset  cust_day_avg  avg_rate_mov_yr  avg_rate_cst_yr  \
# 61342875             0.19          3.97             3.51             3.75
# 12081331             0.47          3.67             3.52             3.94
# 99011741            -0.48          3.71             3.92             4.07
# 73636568            -0.28          3.40             3.50             3.32
# 66797623             0.04          3.67             3.55             3.34
#
#           all_ratings
# 61342875            4
# 12081331            3
# 99011741            4
# 73636568            3
# 66797623            3

# %%
# %%time
# create quiz set from primary df by selecting rows with null values
quiz = net[net.isna().any(axis=1)].copy()

# drop the column 'rating' since it is all nans
quiz.drop(['rating'], 1, inplace=True)

# rename the column that contains the ratings to 'rating'
quiz.rename(columns={'all_ratings': 'rating'}, inplace=True)
quiz.info()
quiz.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1408395 entries, 8994179 to 49941263
# Data columns (total 18 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   mov_id           1408395 non-null  int16
#  1   cust_id          1408395 non-null  int32
#  2   day_rated        1408395 non-null  int16
#  3   mov_year         1408395 non-null  int16
#  4   mov_count        1408395 non-null  int32
#  5   rated_bycust     1408395 non-null  int16
#  6   rate_each_day    1408395 non-null  int32
#  7   mov_day_count    1408395 non-null  uint16
#  8   cust_day_count   1408395 non-null  int16
#  9   mov_avg_rating   1408395 non-null  float32
#  10  cust_avg_rating  1408395 non-null  float32
#  11  mov_day_avg_rl   1408395 non-null  float32
#  12  mov_day_avg      1408395 non-null  float32
#  13  cust_avg_offset  1408395 non-null  float32
#  14  cust_day_avg     1408395 non-null  float32
#  15  avg_rate_mov_yr  1408395 non-null  float32
#  16  avg_rate_cst_yr  1408395 non-null  float32
#  17  rating           1408395 non-null  int8
# dtypes: float32(8), int16(5), int32(3), int8(1), uint16(1)
# memory usage: 87.3 MB
# Wall time: 2.21 s
#           mov_id  cust_id  day_rated  mov_year  mov_count  rated_bycust  \
# 8994179     1798    32439       2044      1987     110574            76
# 88877859   15792  1114824       1710      2003        804            17
# 97938651   17324  1939417       2147      2005     106716            78
# 3085518      571  2162086       2151      1999     150848            50
# 24041226    4493   433805       1921      2003       6215           449
#
#           rate_each_day  mov_day_count  cust_day_count  mov_avg_rating  \
# 8994179          146052            163              76            3.96
# 88877859          72225              2               1            3.75
# 97938651         177424            356               2            3.88
# 3085518          135400            208              37            3.96
# 24041226         161409             43               4            3.14
#
#           cust_avg_rating  mov_day_avg_rl  mov_day_avg  cust_avg_offset  \
# 8994179              3.91            4.05         4.05             0.27
# 88877859             3.25            4.00         4.00            -0.46
# 97938651             3.86            3.64         3.64             0.24
# 3085518              3.48            4.01         4.01            -0.30
# 24041226             3.29            3.00         3.00            -0.15
#
#           cust_day_avg  avg_rate_mov_yr  avg_rate_cst_yr  rating
# 8994179           3.91             3.65             3.33       5
# 88877859          3.62             3.51             3.25       4
# 97938651          2.00             3.55             2.00       4
# 3085518           3.58             3.60             4.75       3
# 24041226          4.50             3.51             3.00       2

# %%
# %%time
# split quiz set into features and target
quiz_target = quiz.drop(['mov_id', 'cust_id', 'day_rated', 'mov_year',
                         'mov_count', 'rated_bycust', 'rate_each_day',
                         'mov_day_count', 'cust_day_count',
                         'mov_avg_rating', 'cust_avg_rating',
                         'mov_day_avg_rl', 'mov_day_avg',
                         'cust_avg_offset', 'cust_day_avg',
                         'avg_rate_mov_yr', 'avg_rate_cst_yr'], 1)
quiz_features = quiz.drop(['rating'], 1)
quiz_target.info()
display(quiz_target.head())
quiz_features.info()
quiz_features.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1408395 entries, 8994179 to 49941263
# Data columns (total 1 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   rating  1408395 non-null  int8
# dtypes: int8(1)
# memory usage: 12.1 MB
#           rating
# 8994179        5
# 88877859       4
# 97938651       4
# 3085518        3
# 24041226       2
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1408395 entries, 8994179 to 49941263
# Data columns (total 17 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   mov_id           1408395 non-null  int16
#  1   cust_id          1408395 non-null  int32
#  2   day_rated        1408395 non-null  int16
#  3   mov_year         1408395 non-null  int16
#  4   mov_count        1408395 non-null  int32
#  5   rated_bycust     1408395 non-null  int16
#  6   rate_each_day    1408395 non-null  int32
#  7   mov_day_count    1408395 non-null  uint16
#  8   cust_day_count   1408395 non-null  int16
#  9   mov_avg_rating   1408395 non-null  float32
#  10  cust_avg_rating  1408395 non-null  float32
#  11  mov_day_avg_rl   1408395 non-null  float32
#  12  mov_day_avg      1408395 non-null  float32
#  13  cust_avg_offset  1408395 non-null  float32
#  14  cust_day_avg     1408395 non-null  float32
#  15  avg_rate_mov_yr  1408395 non-null  float32
#  16  avg_rate_cst_yr  1408395 non-null  float32
# dtypes: float32(8), int16(5), int32(3), uint16(1)
# memory usage: 86.0 MB
# Wall time: 105 ms
#           mov_id  cust_id  day_rated  mov_year  mov_count  rated_bycust  \
# 8994179     1798    32439       2044      1987     110574            76
# 88877859   15792  1114824       1710      2003        804            17
# 97938651   17324  1939417       2147      2005     106716            78
# 3085518      571  2162086       2151      1999     150848            50
# 24041226    4493   433805       1921      2003       6215           449
#
#           rate_each_day  mov_day_count  cust_day_count  mov_avg_rating  \
# 8994179          146052            163              76            3.96
# 88877859          72225              2               1            3.75
# 97938651         177424            356               2            3.88
# 3085518          135400            208              37            3.96
# 24041226         161409             43               4            3.14
#
#           cust_avg_rating  mov_day_avg_rl  mov_day_avg  cust_avg_offset  \
# 8994179              3.91            4.05         4.05             0.27
# 88877859             3.25            4.00         4.00            -0.46
# 97938651             3.86            3.64         3.64             0.24
# 3085518              3.48            4.01         4.01            -0.30
# 24041226             3.29            3.00         3.00            -0.15
#
#           cust_day_avg  avg_rate_mov_yr  avg_rate_cst_yr
# 8994179           3.91             3.65             3.33
# 88877859          3.62             3.51             3.25
# 97938651          2.00             3.55             2.00
# 3085518           3.58             3.60             4.75
# 24041226          4.50             3.51             3.00

# %%
# %%time
# drop the column 'rating' since it is not needed (and float64)
net.drop(['rating'], 1, inplace=True)

# rename the column that contains the ratings to 'rating'
net.rename(columns={'all_ratings': 'rating'}, inplace=True)

# drop the matching rows that belong only in the quiz set
net.drop(quilist, inplace=True)
net.info()
net.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96304740 entries, 61342875 to 6598294
# Data columns (total 18 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   mov_id           int16
#  1   cust_id          int32
#  2   day_rated        int16
#  3   mov_year         int16
#  4   mov_count        int32
#  5   rated_bycust     int16
#  6   rate_each_day    int32
#  7   mov_day_count    uint16
#  8   cust_day_count   int16
#  9   mov_avg_rating   float32
#  10  cust_avg_rating  float32
#  11  mov_day_avg_rl   float32
#  12  mov_day_avg      float32
#  13  cust_avg_offset  float32
#  14  cust_day_avg     float32
#  15  avg_rate_mov_yr  float32
#  16  avg_rate_cst_yr  float32
#  17  rating           int8
# dtypes: float32(8), int16(5), int32(3), int8(1), uint16(1)
# memory usage: 5.8 GB
# Wall time: 27.6 s
#           mov_id  cust_id  day_rated  mov_year  mov_count  rated_bycust  \
# 61342875   11182   549302       1696      2003     103062           459
# 12081331    2342  1077245       1976      2004      87480           139
# 99011741   17474  2463816       1567      1964      32089          1577
# 73636568   13372  2204684       1225      2002        350           829
# 66797623   12191  2032601       1679      1996      12782          1219
#
#           rate_each_day  mov_day_count  cust_day_count  mov_avg_rating  \
# 61342875          70730            296             106            3.55
# 12081331          98810            126               3            3.87
# 99011741          83753             41               7            4.09
# 73636568          15570              1               5            2.69
# 66797623          97725             34               6            2.97
#
#           cust_avg_rating  mov_day_avg_rl  mov_day_avg  cust_avg_offset  \
# 61342875             3.79            3.53         3.53             0.19
# 12081331             4.27            3.72         3.72             0.47
# 99011741             3.08            4.20         4.20            -0.48
# 73636568             3.26            3.00         3.00            -0.28
# 66797623             3.48            2.65         2.65             0.04
#
#           cust_day_avg  avg_rate_mov_yr  avg_rate_cst_yr  rating
# 61342875          3.97             3.51             3.75       4
# 12081331          3.67             3.52             3.94       3
# 99011741          3.71             3.92             4.07       4
# 73636568          3.40             3.50             3.32       3
# 66797623          3.67             3.55             3.34       3

# %%
# %%time
# split training set into features and target
train_target = net.drop(['mov_id', 'cust_id', 'day_rated', 'mov_year',
                         'mov_count', 'rated_bycust', 'rate_each_day',
                         'mov_day_count', 'cust_day_count',
                         'mov_avg_rating', 'cust_avg_rating',
                         'mov_day_avg_rl', 'mov_day_avg',
                         'cust_avg_offset', 'cust_day_avg',
                         'avg_rate_mov_yr', 'avg_rate_cst_yr'], 1)
train_features = net.drop(['rating'], 1)
train_target.info()
print()
train_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96304740 entries, 61342875 to 6598294
# Data columns (total 1 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   rating  int8
# dtypes: int8(1)
# memory usage: 826.6 MB
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96304740 entries, 61342875 to 6598294
# Data columns (total 17 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   mov_id           int16
#  1   cust_id          int32
#  2   day_rated        int16
#  3   mov_year         int16
#  4   mov_count        int32
#  5   rated_bycust     int16
#  6   rate_each_day    int32
#  7   mov_day_count    uint16
#  8   cust_day_count   int16
#  9   mov_avg_rating   float32
#  10  cust_avg_rating  float32
#  11  mov_day_avg_rl   float32
#  12  mov_day_avg      float32
#  13  cust_avg_offset  float32
#  14  cust_day_avg     float32
#  15  avg_rate_mov_yr  float32
#  16  avg_rate_cst_yr  float32
# dtypes: float32(8), int16(5), int32(3), uint16(1)
# memory usage: 5.7 GB
# Wall time: 4.43 s

# %%
# %%time
quiz_target.to_parquet('quiz_target.parquet')
del quiz_target
quiz_features.to_parquet('quiz_features.parquet')
del quiz_features
train_target.to_parquet('train_target.parquet')
del train_target
train_features.to_parquet('train_features.parquet')
# Out:
# Wall time: 29.6 s

# %%
end_time = time.perf_counter()
prog_ex_time = end_time - start_time
print('This program executes in {} seconds.'.format(prog_ex_time))
# Out:
# This program executes in 69.5177171 seconds.

# %% [markdown]
# That's 1 minute and 9.52 seconds.
